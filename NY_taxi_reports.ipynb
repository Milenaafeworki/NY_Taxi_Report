# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/milen/Career services/NY_taxi/May 2019/yellow_tripdata_2019-05.csv')
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2019-05-01 00:14:50   2019-05-01 00:16:48                1
# 1         1  2019-05-01 00:35:54   2019-05-01 00:37:27                1
# 2         1  2019-05-01 00:37:45   2019-05-01 00:37:49                1
# 3         1  2019-05-01 00:44:57   2019-05-01 00:50:11                1
# 4         1  2019-05-01 00:59:48   2019-05-01 01:10:22                1
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0           1                  N           145           145
# 1            1.5           1                  N           145           145
# 2            1.5           1                  N           145           145
# 3            0.7           1                  N           161           161
# 4            2.0           1                  N           163           141
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.shape
# Out:
# (7565261, 18)

# %%
df1 = pd.read_csv('C:/Users/milen/Career services/NY_taxi/May 2020/yellow_tripdata_2020-05.csv')
df1.head()
# Out:
# C:\Users\milen\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2020-05-01 00:02:28   2020-05-01 00:18:07              1.0
# 1       1.0  2020-05-01 00:23:21   2020-05-01 00:26:01              2.0
# 2       1.0  2020-05-01 00:54:58   2020-05-01 00:57:11              1.0
# 3       1.0  2020-05-01 00:07:10   2020-05-01 00:12:46              1.0
# 4       1.0  2020-05-01 00:55:47   2020-05-01 01:01:54              0.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0            0.0         1.0                  N           234           256
# 1            0.4         1.0                  N           264           264
# ...

# %%
df1.shape
# Out:
# (348371, 18)

# %%
df2 = pd.read_csv('C:/Users/milen/Career services/NY_taxi/May 2021/yellow_tripdata_2021-05.csv')
df2.head()
# Out:
# C:\Users\milen\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0       1.0  2021-05-01 00:37:18   2021-05-01 00:41:07              2.0
# 1       1.0  2021-05-01 00:43:01   2021-05-01 00:49:19              1.0
# 2       1.0  2021-05-01 00:05:54   2021-05-01 00:31:46              1.0
# 3       2.0  2021-05-01 00:08:21   2021-05-01 00:19:20              1.0
# 4       2.0  2021-05-01 00:32:44   2021-05-01 00:48:44              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           0.70         1.0                  N           141           263
# 1           1.40         1.0                  N           263            75
# ...

# %%
df2.shape
# Out:
# (2507109, 18)

# %%
import missingno as msno

# %%
# Visualize the number of missing
# values as a bar chart
msno.bar(df);

# %%
msno.bar(df1);

# %%
msno.bar(df2);
